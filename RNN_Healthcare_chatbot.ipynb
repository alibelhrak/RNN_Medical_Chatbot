# %% [markdown]
# <a href="https://colab.research.google.com/github/alibelhrak/RNN_Medical_Chatbot/blob/main/RNN_Healthcare_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Libraries

# %% [markdown]
# for these packages we gonna use:
# * NLTK to tokenize , lemmatize , stemming the dataset text part
# * Tensorflow to build an RNN model With LSTM layer using Keras
# * pandas to load the datset
# * Numpy to make mathematic operations : we used it here to convert texts into arrays

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , Dropout   , Flatten
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import categorical_crossentropy
import nltk
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# # Kaggle Testing Dataset

# %%
pip install opendatasets
# Out:
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from opendatasets) (4.67.1)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (from opendatasets) (1.7.4.2)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from opendatasets) (8.1.8)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (2025.1.31)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (3.4.1)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (3.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (5.29.4)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (1.3)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (2.3.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (0.5.1)
# Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22

# %%
import opendatasets as od
ds1 = od.download('https://www.kaggle.com/datasets/tusharkhete/dataset-for-medicalrelated-chatbots?select=intents.json')
ds3 = od.download('https://www.kaggle.com/datasets/muhammadaneeq786/health-care-dataset/data?select=intents1.json')
menatal_health_ds = od.download('https://www.kaggle.com/datasets/jiscecseaiml/mental-health-dataset?select=KB.json')
ds2 = od.download('https://www.kaggle.com/datasets/thedevastator/comprehensive-medical-q-a-dataset?select=train.csv')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: alibelhrak
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/tusharkhete/dataset-for-medicalrelated-chatbots
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: alibelhrak
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/muhammadaneeq786/health-care-dataset
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: alibelhrak
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/jiscecseaiml/mental-health-dataset
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: alibelhrak
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/thedevastator/comprehensive-medical-q-a-dataset

# %% [markdown]
# *   **I added this New Dataset From Kaggle don't remove it**

# %%
data1 = pd.read_json('/content/dataset-for-medicalrelated-chatbots/intents.json')
data1
# Out:
#                                               intents
# 0   {'tag': 'Cuts', 'patterns': ['What to do if Cu...
# 1   {'tag': 'Abrasions', 'patterns': ['how do you ...
# 2   {'tag': 'stings', 'patterns': ['How do you tre...
# 3   {'tag': 'Splinter', 'patterns': ['How to remov...
# 4   {'tag': 'Sprains', 'patterns': ['How do you tr...
# 5   {'tag': 'Strains', 'patterns': ['How do you tr...
# 6   {'tag': 'Fever', 'patterns': ['How do you trea...
# 7   {'tag': 'Nasal Congestion', 'patterns': ['How ...
# 8   {'tag': 'Cough', 'patterns': ['How to cure cou...
# 9   {'tag': 'Sore Throat', 'patterns': ['How do yo...
# 10  {'tag': 'Gastrointestinal problems', 'patterns...
# 11  {'tag': 'Skin problems', 'patterns': ['How do ...
# 12  {'tag': 'Abdonominal Pain', 'patterns': ['How ...
# 13  {'tag': 'Bruises', 'patterns': ['How do you tr...
# 14  {'tag': 'Broken Toe', 'patterns': ['How do you...
# 15  {'tag': 'Choking', 'patterns': ['How do you tr...
# 16  {'tag': 'Wound', 'patterns': ['How do you trea...
# 17  {'tag': 'Diarrhea', 'patterns': ['How do you t...
# 18  {'tag': 'Frost bite', 'patterns': ['How do you...
# 19  {'tag': 'Heat Exhaustion', 'patterns': ['How d...
# 20  {'tag': 'Heat Stroke', 'patterns': ['How do yo...
# 21  {'tag': 'Insect Bites', 'patterns': ['How do y...
# 22  {'tag': 'nose bleed', 'patterns': ['How do you...
# 23  {'tag': 'Pulled Muscle', 'patterns': ['How do ...
# 24  {'tag': 'Rectal bleeding', 'patterns': ['How d...
# 25  {'tag': 'Sun Burn', 'patterns': ['How do you t...
# 26  {'tag': 'Testicle Pain', 'patterns': ['How do ...
# 27  {'tag': 'Vertigo', 'patterns': ['How do you tr...
# 28  {'tag': 'Normal Bleeding', 'patterns': ['How d...
# 29  {'tag': 'Eye Injury', 'patterns': ['How do you...
# 30  {'tag': 'Chemical Burn', 'patterns': ['How do ...
# 31  {'tag': 'Poison', 'patterns': ['How do you tre...
# 32  {'tag': 'Teeth', 'patterns': ['How do you trea...
# 33  {'tag': 'seizure', 'patterns': ['How do you tr...
# 34  {'tag': 'Head Injury', 'patterns': ['How do yo...
# 35  {'tag': 'Fainting', 'patterns': ['How do you t...
# 36  {'tag': 'Headache', 'patterns': ['How do you t...
# 37  {'tag': 'Cold', 'patterns': ['How do you treat...
# 38  {'tag': 'Rash', 'patterns': ['How do you treat...
# 39  {'tag': 'snake bite', 'patterns': ['How do you...
# 40  {'tag': 'animal bite', 'patterns': ['How do yo...
# 41  {'tag': 'Drowning', 'patterns': ['What to do i...
# 42  {'tag': 'CPR', 'patterns': ['How to give CPR??...
# 43  {'tag': 'Fracture', 'patterns': ['How do you t...

# %%
data2 = pd.read_csv('/content/comprehensive-medical-q-a-dataset/train.csv')

# %%
data2
# Out:
#                  qtype                                           Question  \
# 0       susceptibility  Who is at risk for Lymphocytic Choriomeningiti...
# 1             symptoms  What are the symptoms of Lymphocytic Choriomen...
# 2       susceptibility  Who is at risk for Lymphocytic Choriomeningiti...
# 3      exams and tests  How to diagnose Lymphocytic Choriomeningitis (...
# 4            treatment  What are the treatments for Lymphocytic Chorio...
# ...                ...                                                ...
# 16402         symptoms  What are the symptoms of Familial visceral myo...
# 16403      information              What is (are) Pseudopelade of Brocq ?
# 16404         symptoms   What are the symptoms of Pseudopelade of Brocq ?
# 16405        treatment  What are the treatments for Pseudopelade of Br...
# 16406      information  What is (are) Desmoplastic small round cell tu...
#
#                                                   Answer
# 0      LCMV infections can occur after exposure to fr...
# 1      LCMV is most commonly recognized as causing ne...
# 2      Individuals of all ages who come into contact ...
# 3      During the first phase of the disease, the mos...
# 4      Aseptic meningitis, encephalitis, or meningoen...
# ...                                                  ...
# 16402  What are the signs and symptoms of Familial vi...
# 16403  Pseudopelade of Brocq (PBB) is a slowly progre...
# 16404  What are the signs and symptoms of Pseudopelad...
# 16405  Is there treatment or a cure for pseudopelade ...
# 16406  Desmoplastic small round cell tumors (DSRCT), ...
#
# [16407 rows x 3 columns]

# %%
data3 = pd.read_json('/content/health-care-dataset/intents1.json')

# %%
data3
# Out:
#                                               intents
# 0   {'tag': 'greetings', 'patterns': ['hello', 'he...
# 1   {'context': [''], 'patterns': ['cya', 'see you...
# 2   {'context': [''], 'patterns': ['how old', 'how...
# 3   {'context': [''], 'patterns': ['what is your n...
# 4   {'context': [''], 'patterns': ['I want treatme...
# 5   {'tag': 'What is high blood pressure?', 'patte...
# 6   {'tag': 'What is low blood pressure?', 'patter...
# 7   {'tag': 'What are the symptoms of high blood p...
# 8   {'tag': 'What are the symptoms of low blood pr...
# 9   {'tag': 'How to manage high blood pressure?', ...
# 10  {'tag': 'How to manage low blood pressure?', '...
# 11  {'tag': 'What causes high blood pressure?', 'p...
# 12  {'tag': 'What causes low blood pressure?', 'pa...
# 13  {'tag': 'How is blood pressure measured?', 'pa...
# 14  {'tag': 'Cuts', 'patterns': ['What to do if Cu...
# 15  {'tag': 'Abrasions', 'patterns': ['how do you ...
# 16  {'tag': 'stings', 'patterns': ['How do you tre...
# 17  {'tag': 'Splinter', 'patterns': ['How to remov...
# 18  {'tag': 'Sprains', 'patterns': ['How do you tr...
# 19  {'tag': 'Strains', 'patterns': ['How do you tr...
# 20  {'tag': 'Fever', 'patterns': ['How do you trea...
# 21  {'tag': 'Nasal Congestion', 'patterns': ['How ...
# 22  {'tag': 'Cough', 'patterns': ['How to cure cou...
# 23  {'tag': 'Sore Throat', 'patterns': ['How do yo...
# 24  {'tag': 'Gastrointestinal problems', 'patterns...
# 25  {'tag': 'Skin problems', 'patterns': ['How do ...
# 26  {'tag': 'Abdonominal Pain', 'patterns': ['How ...
# 27  {'tag': 'Bruises', 'patterns': ['How do you tr...
# 28  {'tag': 'Broken Toe', 'patterns': ['How do you...
# 29  {'tag': 'Choking', 'patterns': ['How do you tr...
# 30  {'tag': 'Wound', 'patterns': ['How do you trea...
# 31  {'tag': 'Diarrhea', 'patterns': ['How do you t...
# 32  {'tag': 'Frost bite', 'patterns': ['How do you...
# 33  {'tag': 'Heat Exhaustion', 'patterns': ['How d...
# 34  {'tag': 'Heat Stroke', 'patterns': ['How do yo...
# 35  {'tag': 'Insect Bites', 'patterns': ['How do y...
# 36  {'tag': 'nose bleed', 'patterns': ['How do you...
# 37  {'tag': 'Pulled Muscle', 'patterns': ['How do ...
# 38  {'tag': 'Rectal bleeding', 'patterns': ['How d...
# 39  {'tag': 'Sun Burn', 'patterns': ['How do you t...
# 40  {'tag': 'Testicle Pain', 'patterns': ['How do ...
# 41  {'tag': 'Vertigo', 'patterns': ['How do you tr...
# 42  {'tag': 'Normal Bleeding', 'patterns': ['How d...
# 43  {'tag': 'Eye Injury', 'patterns': ['How do you...
# 44  {'tag': 'Chemical Burn', 'patterns': ['How do ...
# 45  {'tag': 'Poison', 'patterns': ['How do you tre...
# 46  {'tag': 'Teeth', 'patterns': ['How do you trea...
# 47  {'tag': 'seizure', 'patterns': ['How do you tr...
# 48  {'tag': 'Head Injury', 'patterns': ['How do yo...
# 49  {'tag': 'Fainting', 'patterns': ['How do you t...
# 50  {'tag': 'Headache', 'patterns': ['How do you t...
# 51  {'tag': 'Cold', 'patterns': ['How do you treat...
# 52  {'tag': 'Rash', 'patterns': ['How do you treat...
# 53  {'tag': 'snake bite', 'patterns': ['How do you...
# 54  {'tag': 'animal bite', 'patterns': ['How do yo...
# 55  {'tag': 'Drowning', 'patterns': ['What to do i...
# 56  {'tag': 'CPR', 'patterns': ['How to give CPR??...
# 57  {'tag': 'Fracture', 'patterns': ['How do you t...

# %%
menatal_health_data = pd.read_json('/content/mental-health-dataset/KB.json')

# %%
menatal_health_data
# Out:
#                                               intents
# 0   {'tag': 'greeting', 'patterns': ['Hi', 'Hey', ...
# 1   {'tag': 'morning', 'patterns': ['Good morning'...
# 2   {'tag': 'afternoon', 'patterns': ['Good aftern...
# 3   {'tag': 'evening', 'patterns': ['Good evening'...
# 4   {'tag': 'night', 'patterns': ['Good night', 'N...
# ..                                                ...
# 75  {'tag': 'fact-28', 'patterns': ['What do I do ...
# 76  {'tag': 'fact-29', 'patterns': ['How do I know...
# 77  {'tag': 'fact-30', 'patterns': ['How can I mai...
# 78  {'tag': 'fact-31', 'patterns': ['What's the di...
# 79  {'tag': 'fact-32', 'patterns': ['What's the di...
#
# [80 rows x 1 columns]

# %% [markdown]
# # Merging Three Ds into common Ds

# %%
import json
from pathlib import Path

path1 = Path("/content/dataset-for-medicalrelated-chatbots/intents.json")
path2 = Path("/content/health-care-dataset/intents1.json")
path3 = Path("/content/mental-health-dataset/KB.json")

merged_intents = []

with open(path1, 'r') as f:
    data = json.load(f)
    merged_intents.extend(data.get("intents", []))

with open(path2, 'r') as f:
    data = json.load(f)
    merged_intents.extend(data.get("intents", []))

with open(path3, 'r') as f:
    kb_data = json.load(f)
    fact_id = 0
    for entry in kb_data:
        if isinstance(entry, str):
            try:
                entry = json.loads(entry)
            except:
                continue
        if isinstance(entry, dict):
            question = entry.get("Question")
            answer = entry.get("Answer")
            if question and answer:
                merged_intents.append({
                    "tag": f"fact-{fact_id}",
                    "patterns": [question],
                    "responses": [answer]
                })
                fact_id += 1

df = pd.DataFrame({"intents": merged_intents})
df.to_csv("merged_intents_column.csv", index=True)

# %%
df
# Out:
#                                                intents
# 0    {'tag': 'Cuts', 'patterns': ['What to do if Cu...
# 1    {'tag': 'Abrasions', 'patterns': ['how do you ...
# 2    {'tag': 'stings', 'patterns': ['How do you tre...
# 3    {'tag': 'Splinter', 'patterns': ['How to remov...
# 4    {'tag': 'Sprains', 'patterns': ['How do you tr...
# ..                                                 ...
# 97   {'tag': 'snake bite', 'patterns': ['How do you...
# 98   {'tag': 'animal bite', 'patterns': ['How do yo...
# 99   {'tag': 'Drowning', 'patterns': ['What to do i...
# 100  {'tag': 'CPR', 'patterns': ['How to give CPR??...
# 101  {'tag': 'Fracture', 'patterns': ['How do you t...
#
# [102 rows x 1 columns]

# %% [markdown]
# # Data1 Preprocessing

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
lemmatizer = WordNetLemmatizer()
words=[]
classes=[]
documents=[]
ignore_symbols = ['.','?' , ';' , ':' , '!' , '%']
from nltk.tokenize import word_tokenize

for intent in df["intents"]:
    for pattern in intent["patterns"]:
        words_list = word_tokenize(pattern)
        words.append(words_list)
        documents.append((words_list, intent["tag"]))

        if intent["tag"] not in classes:
            classes.append(intent["tag"])

print("Documents:", documents)
# Out:
# Documents: [(['What', 'to', 'do', 'if', 'Cuts', '?'], 'Cuts'), (['How', 'to', 'cure', 'Cuts', '?'], 'Cuts'), (['Which', 'medicine', 'to', 'apply', 'for', 'Cuts', '?'], 'Cuts'), (['what', 'to', 'apply', 'on', 'cuts', '?'], 'Cuts'), (['Cuts'], 'Cuts'), (['how', 'do', 'you', 'treat', 'abrasions', '?'], 'Abrasions'), (['Do', 'Abrasions', 'cause', 'scars', '?'], 'Abrasions'), (['Abrasions'], 'Abrasions'), (['what', 'to', 'do', 'if', 'abrasions', '?'], 'Abrasions'), (['Which', 'medicine', 'to', 'apply', 'for', 'abrasions', '?'], 'Abrasions'), (['How', 'to', 'cure', 'abrasions', '?'], 'Abrasions'), (['How', 'do', 'you', 'treat', 'Sting', '?'], 'stings'), (['Stings'], 'stings'), (['What', 'to', 'do', 'if', 'you', 'get', 'a', 'sting', '?'], 'stings'), (['Which', 'medicine', 'to', 'apply', 'if', 'sting', '?'], 'stings'), (['How', 'to', 'remove', 'Splinters'], 'Splinter'), (['How', 'to', 'cure', 'Splinters', '?'], 'Splinter'), (['What', 'to', 'do', 'if', 'I', 'have', 'splinters', '?'], 'Splinter'), (['How', 'do', 'you', 'bring', 'a', 'splinter', 'to', 'the', 'surface', '?'], 'Splinter'), (['How', 'do', 'you', 'treat', 'a', 'sprain', '?'], 'Sprains'), (['what', 'to', 'do', 'if', 'i', 'get', 'a', 'sprain', '?'], 'Sprains'), (['Which', 'cream', 'to', 'apply', 'if', 'i', 'get', 'a', 'sprain', '?'], 'Sprains'), (['Which', 'medicine', 'to', 'apply', 'if', 'I', 'get', 'a', 'sprain', '?'], 'Sprains'), (['How', 'do', 'you', 'treat', 'a', 'strain', '?'], 'Strains'), (['what', 'to', 'do', 'if', 'i', 'get', 'a', 'strain', '?'], 'Strains'), (['Which', 'cream', 'to', 'apply', 'if', 'i', 'get', 'a', 'strain', '?'], 'Strains'), (['Which', 'medicine', 'to', 'apply', 'if', 'I', 'get', 'a', 'strain', '?'], 'Strains'), (['How', 'do', 'you', 'diagnose', 'a', 'strain', '?'], 'Strains'), (['Is', 'heat', 'or', 'ice', 'better', 'for', 'a', 'pulled', 'muscle', '?'], 'Strains'), (['How', 'do', 'you', 'treat', 'a', 'mild', 'Fever', '?'], 'Fever'), (['what', 'to', 'do', 'if', 'i', 'get', 'a', 'mild', 'fever', '?'], 'Fever'), (['Which', 'medicine', 'to', 'take', 'if', 'I', 'get', 'a', 'mild', 'fever', '?'], 'Fever'), (['fever'], 'Fever'), (['How', 'do', 'you', 'treat', 'nasal', 'Congestion', '?'], 'Nasal Congestion'), (['what', 'to', 'do', 'if', 'i', 'get', 'a', 'nasal', 'congestion', '?'], 'Nasal Congestion'), (['Which', 'medicine', 'to', 'take', 'if', 'I', 'have', 'a', 'nasal', 'congestion', '?'], 'Nasal Congestion'), (['what', 'to', 'do', 'if', 'i', 'have', 'a', 'blocked', 'nose', '?'], 'Nasal Congestion'), (['How', 'do', 'you', 'treat', 'a', 'blocked', 'nose', '?'], 'Nasal Congestion'), (['How', 'long', 'does', 'nasal', 'congestion', 'last', '?'], 'Nasal Congestion'), (['How', 'to', 'cure', 'cough', '?'], 'Cough'), (['How', 'do', 'you', 'treat', 'cough', '?'], 'Cough'), (['what', 'to', 'do', 'if', 'i', 'get', 'a', 'cough', '?'], 'Cough'), (['Which', 'medicine', 'to', 'take', 'if', 'I', 'get', 'cough', '?'], 'Cough'), (['How', 'do', 'you', 'get', 'rid', 'of', 'cough', '?'], 'Cough'), (['How', 'do', 'you', 'treat', 'sore', 'throat', '?'], 'Sore Throat'), (['what', 'to', 'do', 'if', 'i', 'get', 'a', 'sore', 'throat', '?'], 'Sore Throat'), (['Which', 'medicine', 'to', 'take', 'if', 'I', 'get', 'a', 'sore', 'throat', '?'], 'Sore Throat'), (['How', 'to', 'cure', 'sore', 'throat', '?'], 'Sore Throat'), (['How', 'do', 'you', 'treat', 'gas', 'problems', '?'], 'Gastrointestinal problems'), (['what', 'to', 'do', 'if', 'i', 'have', 'Gastrointestinal', 'problems', '?'], 'Gastrointestinal problems'), (['Which', 'medicine', 'to', 'take', 'if', 'I', 'get', 'gas', 'problem', '?'], 'Gastrointestinal problems'), (['How', 'to', 'cure', 'Gas', 'problems', '?'], 'Gastrointestinal problems'), (['How', 'do', 'you', 'treat', 'Skin', 'problems', '?'], 'Skin problems'), (['what', 'to', 'do', 'if', 'i', 'get', 'a', 'skin', 'allergy', '?'], 'Skin problems'), (['Which', 'medicine', 'to', 'take', 'if', 'I', 'get', 'a', 'skin', 'allergy', '?'], 'Skin problems'), (['How', 'to', 'cure', 'skin', ' ...

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %% [markdown]
# *   Lemmatizing the words of each intent in the data to make it easier in the vectorization
# *   then put all the lemmatized words in classes

# %%
words = [lemmatizer.lemmatize(word) for sublist in words for word in sublist if word not in ignore_symbols]
words = list(sorted(set(words)))
classes = list(sorted(set(classes)))

# %%
import random
training = []
output_empty = [0] * len(classes)

for document in documents:
  bag=[]
  word_patterns = document[0]
  word_patterns =[lemmatizer.lemmatize(word) for word in word_patterns]
  for word in words:
    bag.append(1) if word in word_patterns else bag.append(0)
  outputrow = list(output_empty)
  outputrow[classes.index(document[1])] = 1
  training.append([bag  , outputrow])

random.shuffle(training)
training = np.array(training, dtype=object)
train_x = list(training[: , 0])
train_y = list(training[: , 1])

# %% [markdown]
# *   I didn't start the second , third and fourth Data tomorrow i'll finish them after NosQl exam
# * right now one dataset is enough but we have to prepare the other datasets for better performence

# %% [markdown]
# # Data2 Preprocessing
#
# ---

# %% [markdown]
# # Data3 Preprocessing

# %% [markdown]
# # Mental Health Data

# %% [markdown]
# # Building Model

# %%
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(len(train_x[0]),)))
model.add(Dropout(0.25))
model.add(Dense(64 , activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(len(train_y[0]) , activation = 'softmax'))

sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(optimizer = sgd ,  metrics=['accuracy'] , loss='categorical_crossentropy' )
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │        26,368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 58)             │         3,770 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,394 (149.98 KB)
#  Trainable params: 38,394 (149.98 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Training Model

# %%
model.fit(np.array(train_x) , np.array(train_y) , epochs=200 , batch_size =5 , verbose=0)

# %% [markdown]
# # Building ChatBot

# %%
import random
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
ignore_symbols = ['?', '!', '.', ',', "'s", "'m"]

def clean_up(sentence):
    sentence_words = word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words if word not in ignore_symbols]
    return sentence_words

def bag_of_words(sentence):
    sentence_words = clean_up(sentence)
    bag = [0] * len(words)
    for w in sentence_words:
        for i, word in enumerate(words):
            if word == w:
                bag[i] = 1
    return np.array(bag)

def predict_class(sentence):
    bow = bag_of_words(sentence)
    predicted_word = model.predict(np.array([bow]))[0]
    ERROR_THRESHOLD = 0.1

    results = [[i, r] for i, r in enumerate(predicted_word) if r > ERROR_THRESHOLD]
    results.sort(key=lambda x: x[1], reverse=True)

    print(f"DEBUG: Results after threshold: {results}")

    return_list = []
    for r in results:
        return_list.append({'intent': classes[r[0]], 'probability': str(r[1])})

    print(f"DEBUG: Return list: {return_list}")

    return return_list

def get_responses(intent_list, intent_json):
    tag = intent_list[0]['intent']
    list_of_intents = intent_json['intents']
    for i in list_of_intents:
        if i['tag'] == tag:
            result = random.choice(i['responses'])
            break
    return result

while True:
    message = input("Vous: ")

    if message.lower() in ['quit', 'exit', 'goodbye']:
        print("Chatbot: Thanks for this conversation! Goodbye 😊")
        break

    ints = predict_class(message)

    if not ints:
        print("Chatbot: Sorry, this message contains things beyond my knowledge!")
    else:
        res = get_responses(ints, df)
        print("Chatbot:", res)
# Out:
# Vous: hi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# DEBUG: Results after threshold: [[51, np.float32(0.99979335)]]
# DEBUG: Return list: [{'intent': 'greetings', 'probability': '0.99979335'}]
# Chatbot: hey!
# Vous: how you can help me
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DEBUG: Results after threshold: [[52, np.float32(0.49991512)], [57, np.float32(0.29444292)], [48, np.float32(0.17762981)]]
# DEBUG: Return list: [{'intent': 'name', 'probability': '0.49991512'}, {'intent': 'treatment', 'probability': '0.29444292'}, {'intent': 'age', 'probability': '0.17762981'}]
# Chatbot: i am Medbot your medical assistant
# Vous: i get injured what should i do ?
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DEBUG: Results after threshold: [[12, np.float32(0.33155763)], [18, np.float32(0.23933597)], [41, np.float32(0.116769634)], [52, np.float32(0.1032218)]]
# DEBUG: Return list: [{'intent': 'Eye Injury', 'probability': '0.33155763'}, {'intent': 'Head Injury', 'probability': '0.23933597'}, {'intent': 'What are the symptoms of high blood pressure?', 'probability': '0.116769634'}, {'intent': 'name', 'probability': '0.1032218'}]
# Chatbot: 1) DO NOT rub the eye, 2)Blink several times and allow tears to flush out the particle, 3) Lift the upper eyelid over the lashes of your lower lid to let the eyelashes try to brush the particle out., 4) Use eyewash, saline solution or running tap water to flush the eye out
# Vous: no i get injured in my arm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DEBUG: Results after threshold: [[36, np.float32(0.37375894)], [12, np.float32(0.20226201)], [18, np.float32(0.1838849)], [35, np.float32(0.13094822)]]
# DEBUG: Return list: [{'intent': 'Strains', 'probability': '0.37375894'}, {'intent': 'Eye Injury', 'probability': '0.20226201'}, {'intent': 'Head Injury', 'probability': '0.1838849'}, {'intent': 'Sprains', 'probability': '0.13094822'}]
# Chatbot: Rest,Ice,Compression and Elevation can be used to cure strains. Avoid using your muscle for a few days, especially if movement causes an increase in pain and also Apply ice immediately after injuring your muscle. This will minimize swelling. Don’t put ice directly on your skin. Use an ice pack or wrap ice in a towel. To reduce swelling, wrap the affected area with an elastic bandage until swelling comes down.
# Vous: so can you tell me what kind of risks i can face
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# DEBUG: Results after threshold: [[52, np.float32(0.99992657)]]
# DEBUG: Return list: [{'intent': 'name', 'probability': '0.99992657'}]
# Chatbot: you can call me Medbot!
# Vous: what you know about medication ?
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DEBUG: Results after threshold: [[52, np.float32(0.99718827)]]
# DEBUG: Return list: [{'intent': 'name', 'probability': '0.99718827'}]
# Chatbot: i am Medbot!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-31e618a6b929> in <cell line: 0>()
#      49
#      50 while True:
# ---> 51     message = input("Vous: ")
#      52
#      53     if message.lower() in ['quit', 'exit', 'goodbye']:
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
